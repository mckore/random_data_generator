# %%
import csv
import pandas as pd
# Out:
# Running cells with 'Python 3.7.9 ('.venv': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/mkore/WIP/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import json
from cryptography.fernet import Fernet

# %%
with open

# %%
  def decrypt_string(key: str, subject: str) -> str:
        """ Fernet decrypt subject using key. """
        return Fernet(key.encode()).decrypt(subject.encode()).decode()

# %%
k = "gAAAAABhlWx7Lcn6imnwsAIq6GJvsLLQgTDB-EAYHK4ZrSAWbo7mdhL65YnZEF54gIDJDj-GntGrbJZBgdCIRvOScL6anIyV90ZlBDsZyzf4vvd1bx4x5UHjM96fCUDSAZwF92OK66Mj"

# %%
c = k.encode()

# %%
f = Fernet.generate_key()

# %%
fr = Fernet(f)

# %%
fr.decrypt(c).decode()
# Out:
# ---------------------------------------------------------------------------
# InvalidSignature                          Traceback (most recent call last)
# File ~/WIP/.venv/lib/python3.9/site-packages/cryptography/fernet.py:120, in Fernet._verify_signature(self, data)
#     <a href='file:///Users/mkore/WIP/.venv/lib/python3.9/site-packages/cryptography/fernet.py?line=118'>119</a> try:
# --> <a href='file:///Users/mkore/WIP/.venv/lib/python3.9/site-packages/cryptography/fernet.py?line=119'>120</a>     h.verify(data[-32:])
#     <a href='file:///Users/mkore/WIP/.venv/lib/python3.9/site-packages/cryptography/fernet.py?line=120'>121</a> except InvalidSignature:
#
# File ~/WIP/.venv/lib/python3.9/site-packages/cryptography/hazmat/primitives/hmac.py:69, in HMAC.verify(self, signature)
#      <a href='file:///Users/mkore/WIP/.venv/lib/python3.9/site-packages/cryptography/hazmat/primitives/hmac.py?line=67'>68</a> ctx, self._ctx = self._ctx, None
# ...

# %%
ar_store = pd.read_csv('/Users/mkore/WIP/AR_ATD_output.csv', header = 'infer')

# %%
#ar_store.columns[4:15]
store1 = ar_store[ar_store.columns[4:15]].groupby(by = ['location_cd', 'customer_nm', 'dba_nm', 'address', 'city_nm']).count()
store1
# Out:
#                                                                                                     customer_cd  \
# location_cd customer_nm              dba_nm                          address             city_nm
# 732494      JACOB GREGORY            SUNDOWN TIRE & LUBE             PO BOX 905          SUNDOWN              9
#             SUNDOWN TIRE & LUBE, LLC SUNDOWN TIRE & LUBE             PO BOX 905          SUNDOWN              4
# 732495      JACOB GREGORY            SUNDOWN TIRE & LUBE             903 S SLAUGHTER AVE SUNDOWN             87
#             SUNDOWN TIRE & LUBE, LLC SUNDOWN TIRE & LUBE             903 S SLAUGHTER AVE SUNDOWN             21
# 1136805     JACOB GREGORY            HOMETOWN TIRE                   801 HIGHWAY 62      WOLFFORTH            1
#                                                                      839 HIGHWAY 62      WOLFFORTH           18
# ...

# %%
store1
# Out:
#                                                                                                     customer_cd  \
# location_cd customer_nm              dba_nm                          address             city_nm
# 732494      JACOB GREGORY            SUNDOWN TIRE & LUBE             PO BOX 905          SUNDOWN              9
#             SUNDOWN TIRE & LUBE, LLC SUNDOWN TIRE & LUBE             PO BOX 905          SUNDOWN              4
# 732495      JACOB GREGORY            SUNDOWN TIRE & LUBE             903 S SLAUGHTER AVE SUNDOWN             87
#             SUNDOWN TIRE & LUBE, LLC SUNDOWN TIRE & LUBE             903 S SLAUGHTER AVE SUNDOWN             21
# 1136805     JACOB GREGORY            HOMETOWN TIRE                   801 HIGHWAY 62      WOLFFORTH            1
#                                                                      839 HIGHWAY 62      WOLFFORTH           18
# ...

# %%
store1.drop_duplicates().groupby(by = ['location_cd', 'address']).count()
# Out:
#                                  customer_cd  dba_nm  customer_nm  city_nm  \
# location_cd address
# 732494      PO BOX 905                     4       4            4        4
# 732495      903 S SLAUGHTER AVE            2       2            2        2
# 1136805     801 HIGHWAY 62                 4       4            4        4
#             839 HIGHWAY 62                 1       1            1        1
# 1485322     801 HIGHWAY 62                 2       2            2        2
# 1494807     211 COLLEGE AVE                2       2            2        2
# 1688806     1700 W 24TH ST                 2       2            2        2
#
#                                  state_cd  county_nm  zip_cd  phone_no  \
# location_cd address
# 732494      PO BOX 905                  4          4       4         3
# 732495      903 S SLAUGHTER AVE         2          2       2         2
# 1136805     801 HIGHWAY 62              4          4       4         4
# ...
